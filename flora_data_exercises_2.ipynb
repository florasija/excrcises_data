# %% [markdown]
# <a href="https://colab.research.google.com/github/florasija/excrcises_data/blob/main/flora_data_exercises_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("souravsv/sample-csv-datasets")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 13.8M/13.8M [00:00<00:00, 46.0MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/souravsv/sample-csv-datasets/versions/1

# %%
#import

import pandas as pd
import numpy as np
from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/root/.cache/kagglehub/datasets/souravsv/sample-csv-datasets/versions/1/HousePrices.csv')
df.head()
# Out:
#    Id  Dwell_Type Zone_Class  LotFrontage  LotArea Road_Type Alley  \
# 0   1          60         RL         65.0     8450      Pave   NaN
# 1   2          20         RL         80.0     9600      Pave   NaN
# 2   3          60         RL         68.0    11250      Pave   NaN
# 3   4          70         RL         60.0     9550      Pave   NaN
# 4   5          60         RL         84.0    14260      Pave   NaN
#
#   Property_Shape LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature  \
# 0            Reg         Lvl    AllPub  ...        0    NaN   NaN         NaN
# 1            Reg         Lvl    AllPub  ...        0    NaN   NaN         NaN
# 2            IR1         Lvl    AllPub  ...        0    NaN   NaN         NaN
# 3            IR1         Lvl    AllPub  ...        0    NaN   NaN         NaN
# 4            IR1         Lvl    AllPub  ...        0    NaN   NaN         NaN
#
#   MiscVal MoSold YrSold  SaleType  SaleCondition  Property_Sale_Price
# ...

# %%
#mwmpwerlihatkan column

print(df.columns)
# Out:
# Index(['Id', 'Dwell_Type', 'Zone_Class', 'LotFrontage', 'LotArea', 'Road_Type',
#        'Alley', 'Property_Shape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'Dwelling_Type', 'HouseStyle', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'MasVnrArea', 'ExterQual', 'ExterCond',
#        'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1',
#        'BsmtFinSF1', 'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF',
#        '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath',
#        'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
# ...

# %%
#memperlihatkan isi column

columnfirst = df['LotArea']
print(columnfirst)
# Out:
# 0        8450
# 1        9600
# 2       11250
# 3        9550
# 4       14260
#         ...
# 1455     7917
# 1456    13175
# 1457     9042
# 1458     9717
# 1459     9937
# Name: LotArea, Length: 1460, dtype: int64

# %%
#medefinisikan unik value untuk kode yang bawah

unique_values = df['LotArea'].value_counts()

# %%
df['neighboorhood'].plot(kind='hist', bins=40, title='Lot Area Distribution')
plt.gca().set_xlabel('Lot Area')
plt.gca().set_ylabel('Frequency')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-836580d537b0> in <cell line: 1>()
# ----> 1 print(df.columns)
#
# NameError: name 'df' is not defined
