# %% [markdown]
# <a href="https://colab.research.google.com/github/florasija/excrcises_data/blob/main/flora_data_exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # > Indented block
# MELIHAT DATASET

# %%
#import

import pandas as pd
import numpy as np
from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#read dataset

df=pd.read_csv('water_potability.csv')
df
# Out:
# ls: cannot access '/root/.cache/kagglehub/datasets/souravsv/sample-csv-datasets/versions/1': No such file or directory

# %%
#Menampilkan dataset atas
df.head()
# Out:
#          ph    Hardness        Solids  Chloramines     Sulfate  Conductivity  \
# 0       NaN  204.890455  20791.318981     7.300212  368.516441    564.308654
# 1  3.716080  129.422921  18630.057858     6.635246         NaN    592.885359
# 2  8.099124  224.236259  19909.541732     9.275884         NaN    418.606213
# 3  8.316766  214.373394  22018.417441     8.059332  356.886136    363.266516
# 4  9.092223  181.101509  17978.986339     6.546600  310.135738    398.410813
#
#    Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       10.379783        86.990970   2.963135           0
# 1       15.180013        56.329076   4.500656           0
# 2       16.868637        66.420093   3.055934           0
# 3       18.436524       100.341674   4.628771           0
# 4       11.558279        31.997993   4.075075           0

# %%
#Menampilkan dataset terbawah
df.tail()
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 3271  4.668102  193.681735  47580.991603     7.166639  359.948574
# 3272  7.808856  193.553212  17329.802160     8.061362         NaN
# 3273  9.419510  175.762646  33155.578218     7.350233         NaN
# 3274  5.126763  230.603758  11983.869376     6.303357         NaN
# 3275  7.874671  195.102299  17404.177061     7.509306         NaN
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 3271    526.424171       13.894419        66.687695   4.435821           1
# 3272    392.449580       19.903225              NaN   2.798243           1
# 3273    432.044783       11.039070        69.845400   3.298875           1
# 3274    402.883113       11.168946        77.488213   4.708658           1
# 3275    327.459760       16.140368        78.698446   2.309149           1

# %%
#Menampilkan informasi dataset
df.shape
# Out:
# (3276, 10)

# %%
#Melihat tipe data variabel di dataset
df.dtypes
# Out:
# ph                 float64
# Hardness           float64
# Solids             float64
# Chloramines        float64
# Sulfate            float64
# Conductivity       float64
# Organic_carbon     float64
# Trihalomethanes    float64
# Turbidity          float64
# Potability           int64
# dtype: object

# %%
#Menampilkan informasi dari dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3276 entries, 0 to 3275
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ph               2785 non-null   float64
#  1   Hardness         3276 non-null   float64
#  2   Solids           3276 non-null   float64
#  3   Chloramines      3276 non-null   float64
#  4   Sulfate          2495 non-null   float64
#  5   Conductivity     3276 non-null   float64
#  6   Organic_carbon   3276 non-null   float64
#  7   Trihalomethanes  3114 non-null   float64
#  8   Turbidity        3276 non-null   float64
#  9   Potability       3276 non-null   int64
# dtypes: float64(9), int64(1)
# memory usage: 256.1 KB

# %%
#mendeskripsikan dataset

df.describe()
# Out:
#                 ph     Hardness        Solids  Chloramines      Sulfate  \
# count  2785.000000  3276.000000   3276.000000  3276.000000  2495.000000
# mean      7.080795   196.369496  22014.092526     7.122277   333.775777
# std       1.594320    32.879761   8768.570828     1.583085    41.416840
# min       0.000000    47.432000    320.942611     0.352000   129.000000
# 25%       6.093092   176.850538  15666.690297     6.127421   307.699498
# 50%       7.036752   196.967627  20927.833607     7.130299   333.073546
# 75%       8.062066   216.667456  27332.762127     8.114887   359.950170
# max      14.000000   323.124000  61227.196008    13.127000   481.030642
#
#        Conductivity  Organic_carbon  Trihalomethanes    Turbidity   Potability
# count   3276.000000     3276.000000      3114.000000  3276.000000  3276.000000
# mean     426.205111       14.284970        66.396293     3.966786     0.390110
# std       80.824064        3.308162        16.175008     0.780382     0.487849
# ...

# %%
#Melihat data yang bersifat numerikal

numerikal = [var for var in df.columns if df[var].dtype!='O']
print('ada {} numerikal variabel\n'.format(len(numerikal)))
df[numerikal].head()
# Out:
# ada 10 numerikal variabel
#          ph    Hardness        Solids  Chloramines     Sulfate  Conductivity  \
# 0       NaN  204.890455  20791.318981     7.300212  368.516441    564.308654
# 1  3.716080  129.422921  18630.057858     6.635246         NaN    592.885359
# 2  8.099124  224.236259  19909.541732     9.275884         NaN    418.606213
# 3  8.316766  214.373394  22018.417441     8.059332  356.886136    363.266516
# 4  9.092223  181.101509  17978.986339     6.546600  310.135738    398.410813
#
#    Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       10.379783        86.990970   2.963135           0
# 1       15.180013        56.329076   4.500656           0
# 2       16.868637        66.420093   3.055934           0
# 3       18.436524       100.341674   4.628771           0
# 4       11.558279        31.997993   4.075075           0

# %%
#Melihat data kategorikal

kategorikal=[var for var in df.columns if df[var].dtype=='O']
print('ada {} kategorikal variabel\n'.format(len(kategorikal)))
df[kategorikal].head()
# Out:
# ada 0 kategorikal variabel
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4]

# %%
#Melihat nilai unik variabel

N_U = df.nunique()
N_U
# Out:
# ph                 2785
# Hardness           3276
# Solids             3276
# Chloramines        3276
# Sulfate            2495
# Conductivity       3276
# Organic_carbon     3276
# Trihalomethanes    3114
# Turbidity          3276
# Potability            2
# dtype: int64

# %%
#Visual Nilai Unik

fig = plt.figure(figsize=(12,5))
plt.bar(df.columns, N_U)

def addlabels(x,y):
    for i in range(len(x)):
        plt.text(i, y[i]//2, y[i], ha = 'center')
addlabels(df.columns, N_U)

fig.suptitle('visualisasi nilai unik di dataset', fontsize=20)
plt.xlabel('Variabel', fontsize=20)
# Out:
# Text(0.5, 0, 'Variabel')

# %%
#Visualisasi Missing Value

fig = plt.figure(figsize=(12,5))
plt.bar(df.columns, missing_value)

def addlabels(x,y):
    for i in range(len(x)):
        plt.text(i, y[i]//2, y[i], ha = 'center')
addlabels(df.columns, missing_value)

fig.suptitle('Visualisasi Missing Value dari Dataset', fontsize=20)
plt.xlabel('Variabel', fontsize=20)
# Out:
# Text(0.5, 0, 'Variabel')

# %%
#Menampilkan outliers dalam grsfik

plt.figure(figsize=(15,10))

plt.subplot(2, 2, 1)
fig = df.boxplot(column='ph')
fig.set_ylabel('ph')

plt.subplot(2, 2, 2)
fig = df.boxplot(column='Hardness')
fig.set_ylabel('Hardness')

plt.subplot(2, 2, 3)
fig = df.boxplot(column='Solids')
fig.set_ylabel('Solids')

plt.subplot(2, 2, 4)
fig = df.boxplot(column='Chloramines')
fig.set_ylabel('Chloramines')
# Out:
# Text(0, 0.5, 'Chloramines')

# %%
#Menampilkan outliers garfik

plt.figure(figsize=(15,10))


plt.subplot(2, 2, 1)
fig = df.boxplot(column='Sulfate')
fig.set_ylabel('Sulfate')

plt.subplot(2, 2, 2)
fig = df.boxplot(column='Conductivity')
fig.set_ylabel('Conductivity')

plt.subplot(2, 2, 1)
fig = df.boxplot(column='Organic_carbon')
fig.set_ylabel('Organic_carbon')

plt.subplot(2, 2, 3)
fig = df.boxplot(column='Trihalomethanes')
fig.set_ylabel('Trihalomethanes')

plt.subplot(2, 2, 4)
fig = df.boxplot(column='Turbidity')
fig.set_ylabel('Turbidity')
# Out:
# Text(0, 0.5, 'Turbidity')

# %%
#Menampilkan histogram persebaran data

df.hist(bins=10, figsize=(20,20), )

plt.show()

# %%
#Melihat missing value

missing_value = df.isnull().sum()
missing_value
# Out:
# ph                 491
# Hardness             0
# Solids               0
# Chloramines          0
# Sulfate            781
# Conductivity         0
# Organic_carbon       0
# Trihalomethanes    162
# Turbidity            0
# Potability           0
# dtype: int64

# %%
#visual apakah air layak di minum(1) artau tidak(0)

plt.figure(figsize = (12,8))
sns.scatterplot(y = df['Potability'], x = df['Turbidity'], hue = df['Potability'])
plt.show()

# %%
#melihat korelasi

korelasi = df.corr()
sns.heatmap(korelasi, square=True, annot=True, fmt='.2f', linecolor='white')
# Out:
# <Axes: >

# %%
#menghiting dalam sulfate

df['Sulfate'].value_counts()
# Out:
# 1119    782
# 2232    135
# 0       129
# 138       1
# 239       1
#        ...
# 511       1
# 680       1
# 417       1
# 262       1
# 1742      1
# Name: Sulfate, Length: 2233, dtype: int64

# %%
#menghiting dalam Trihalomethanes

df['Trihalomethanes'].value_counts()
# Out:
# 66.622485     162
# 26.619225      29
# 106.695040     25
# 84.798956       1
# 75.114888       1
#              ...
# 70.168389       1
# 81.592362       1
# 77.286551       1
# 73.115053       1
# 78.698446       1
# Name: Trihalomethanes, Length: 3063, dtype: int64

# %%
#menghiting dalam ph

df['ph'].value_counts()
# Out:
# 1326    492
# 2644     75
# 0        67
# 2515      1
# 2614      1
#        ...
# 521       1
# 1479      1
# 2527      1
# 1622      1
# 1903      1
# Name: ph, Length: 2645, dtype: int64

# %%
#mengisi null

df['Trihalomethanes'] = df['Trihalomethanes'].fillna("66.622485")

# %%
#mengisi null

df['Sulfate'] = df['Sulfate'].fillna("1119")

# %%
#mengisi null

df['ph'] = df['ph'].fillna("1326")

# %%
#Mengatasi Nilai Nan
df['ph'] = df['ph'].fillna(df['ph'].median())
df['Trihalomethanes'] = df['Trihalomethanes'].fillna(df['Trihalomethanes'].median())
df['Sulfate'] = df['Sulfate'].fillna(df['Sulfate'].median())

# %%
#Mengechek missing value

missing_value = df.isnull().sum()
missing_value
# Out:
# ph                 0
# Hardness           0
# Solids             0
# Chloramines        0
# Sulfate            0
# Conductivity       0
# Organic_carbon     0
# Trihalomethanes    0
# Turbidity          0
# Potability         0
# dtype: int64

# %% [markdown]
# OUTLIER

# %%
#Mengatasi Outlier

features_with_outliers = ['ph','Hardness', 'Solids','Chloramines','Sulfate', 'Conductivity', 'Organic_carbon', 'Trihalomethanes', 'Turbidity', 'Potability']
for feature in features_with_outliers:
    q1 = df[feature].quantile(0.25)
    q3 = df[feature].quantile(0.75)
    IQR = q3-q1
    lower_limit = q1 - (IQR*1.5)
    upper_limit = q3 + (IQR*1.5)
    df.loc[df[feature]<lower_limit,feature]=lower_limit
    df.loc[df[feature]>upper_limit,feature]=upper_limit

# %%
#Mengecheck outliers

plt.figure(figsize=(15,10))

plt.subplot(2, 2, 1)
fig = df.boxplot(column='ph')
fig.set_ylabel('ph')

plt.subplot(2, 2, 2)
fig = df.boxplot(column='Hardness')
fig.set_ylabel('Hardness')

plt.subplot(2, 2, 3)
fig = df.boxplot(column='Solids')
fig.set_ylabel('Solids')

plt.subplot(2, 2, 4)
fig = df.boxplot(column='Chloramines')
fig.set_ylabel('Chloramines')
# Out:
# Text(0, 0.5, 'Chloramines')

# %%
#Mengchek

plt.figure(figsize=(15,10))


plt.subplot(2, 2, 1)
fig = df.boxplot(column='Sulfate')
fig.set_ylabel('Sulfate')

plt.subplot(2, 2, 2)
fig = df.boxplot(column='Conductivity')
fig.set_ylabel('Conductivity')

plt.subplot(2, 2, 1)
fig = df.boxplot(column='Organic_carbon')
fig.set_ylabel('Organic_carbon')

plt.subplot(2, 2, 3)
fig = df.boxplot(column='Trihalomethanes')
fig.set_ylabel('Trihalomethanes')

plt.subplot(2, 2, 4)
fig = df.boxplot(column='Turbidity')
fig.set_ylabel('Turbidity')
# Out:
# Text(0, 0.5, 'Turbidity')

# %%
plt.figure(figsize=(15,10))


plt.subplot(2, 2, 1)
fig = df.boxplot(column='Potability')
fig.set_ylabel('Potability')
# Out:
# Text(0, 0.5, 'Potability')

# %% [markdown]
# kolerasi

# %%
#korelasi

korelasi = df.corr()
korelasi
# Out:
#                        ph  Hardness    Solids  Chloramines   Sulfate  \
# ph               1.000000  0.089394 -0.078025    -0.037922  0.018385
# Hardness         0.089394  1.000000 -0.048503    -0.026343 -0.076900
# Solids          -0.078025 -0.048503  1.000000    -0.070861 -0.142546
# Chloramines     -0.037922 -0.026343 -0.070861     1.000000  0.026113
# Sulfate          0.018385 -0.076900 -0.142546     0.026113  1.000000
# Conductivity     0.018636 -0.025095  0.013177    -0.021890 -0.009160
# Organic_carbon   0.036295  0.002458  0.011816    -0.013184  0.023376
# Trihalomethanes  0.002519 -0.012780 -0.011915     0.015368 -0.025674
# Turbidity       -0.035727 -0.015588  0.020995     0.001729 -0.011458
# Potability      -0.001683 -0.013360  0.031847     0.023523 -0.015506
#
#                  Conductivity  Organic_carbon  Trihalomethanes  Turbidity  \
# ph                   0.018636        0.036295         0.002519  -0.035727
# ...

# %% [markdown]
# string jadi numerik

# %%
#Mengganti tipe data sting jadi numerik

label_encoder = LabelEncoder()
df['ph'] = label_encoder.fit_transform(df['ph'])
label_encoder = LabelEncoder()
df['Hardness'] = label_encoder.fit_transform(df['Hardness'])
label_encoder = LabelEncoder()
df['Solids'] = label_encoder.fit_transform(df['Solids'])

# %%
#Mengganti tipe data string jadi numerik(part2)

label_encoder = LabelEncoder()
df['Chloramines'] = label_encoder.fit_transform(df['Chloramines'])
label_encoder = LabelEncoder()
df['Sulfate'] = label_encoder.fit_transform(df['Sulfate'])
label_encoder = LabelEncoder()
df['Conductivity'] = label_encoder.fit_transform(df['Conductivity'])
label_encoder = LabelEncoder()
df['Organic_carbon'] = label_encoder.fit_transform(df['Organic_carbon'])
label_encoder = LabelEncoder()
df['Turbidity'] = label_encoder.fit_transform(df['Turbidity'])
label_encoder = LabelEncoder()
df['Potability'] = label_encoder.fit_transform(df['Potability'])

# %%
#mengechek head

df.head()
# Out:
#      ph  Hardness  Solids  Chloramines  Sulfate  Conductivity  Organic_carbon  \
# 0  1326      1954    1619         1761     1881          3104             357
# 1     0        43    1283         1198     1119          3195            1989
# 2  2041      2633    1466         2967     1119          1589            2537
# 3  2167      2330    1794         2380     1691           782            2919
# 4  2443       931    1175         1121      535          1278             651
#
#    Trihalomethanes  Turbidity  Potability
# 0        86.990970        332           0
# 1        56.329076       2448           0
# 2        66.420093        397           0
# 3       100.341674       2618           0
# 4        31.997993       1804           0

# %%
#mengecheck tail

df.tail()
# Out:
#         ph  Hardness  Solids  Chloramines  Sulfate  Conductivity  \
# 3271    96      1467    3229         1644     1742          2892
# 3272  1858      1460    1068         2381     1119          1189
# 3273  2515       746    2917         1804     1119          1792
# 3274   217      2794     354          930     1119          1361
# 3275  1903      1518    1079         1946     1119           353
#
#       Organic_carbon  Trihalomethanes  Turbidity  Potability
# 3271            1476        66.687695       2372           1
# 3272            3126        66.622485        204           1
# 3273             506        69.845400        636           1
# 3274             549        77.488213       2706           1
# 3275            2321        78.698446         49           1

# %%
#visual distribusi tipe data

fig, axarr = plt.subplots(1, 2, figsize=(20, 8))

df.dtypes.value_counts().plot.pie(explode=[0.1, 0], autopct='%1.1f%%', shadow=True, ax=axarr[1])
axarr[1].set_title("tipe data]", fontsize=18)

df.dtypes.value_counts().plot(kind='bar', ax=axarr[0])
axarr[0].set_title("Tipe data", fontsize=18)

plt.suptitle('distribus data', fontsize=20)
plt.show()

# %%
f=plt.figure(figsize=(20,5))

f.add_subplot(1,10,1)
sns.countplot(df['ph'])

f.add_subplot(1,10,2)
sns.countplot(df['Hardness'])

f.add_subplot(1,10,3)
sns.countplot(df['Solids'])

f.add_subplot(1,10,4)
sns.countplot(df['Chloramines'])

f.add_subplot(1,10,5)
sns.countplot(df['Conductivity'])

f.add_subplot(1,10,6)
sns.countplot(df['Organic_carbon'])

f.add_subplot(1,10,7)
sns.countplot(df['Trihalomethanes'])

f.add_subplot(1,10,8)
sns.countplot(df['Turbidity'])

f.add_subplot(1,10,9)
sns.countplot(df['Potability'])
# Out:
# <Axes: ylabel='count'>
